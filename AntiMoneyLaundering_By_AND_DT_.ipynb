# %%
import pandas as pd
import pyodbc
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as pyplt
# %matplotlib inline

# %%
# %load_ext sql

# %%
# %sql mssql+pyodbc://AntiLaundering:AntiLaundering@sql_server

# %%
{
    "tags": [
        "output_scroll",
    ]
}
# Out:
# {'tags': ['output_scroll']}

# %%
# %sql SELECT top(1000) [TXN_ID]      ,[TOTAL_TNX]      ,[SUSPECTFRAUD]      ,[DEBIT_CUSTOMER]      ,[USD_EQUIV_BALANCE]      ,[CREDIT_AMOUNT]      ,[AGE]      ,[GENDER]      ,[REGIONNAME]      ,[DISTRICTNAME]  FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND]
# Out:
#  * mssql+pyodbc://AntiLaundering:***@sql_server
# Done.
# [(1, 8, 0, 4599132, Decimal('29827.8000'), Decimal('1577540.0000'), 42, 'MALE', 'OROMIYA', 'MERKATO'),
#  (2, 4, 0, 4530324, Decimal('5545.9700'), Decimal('292500.0000'), 47, 'MALE', 'BENSHANGUL GUMUZ', 'NEKEMTE'),
#  (3, 11, 0, 1456210, Decimal('4705.6500'), Decimal('248200.0000'), 56, 'MALE', 'OROMIYA', 'MEGENAGNA'),
#  (5, 6, 0, 947470, Decimal('20301.8700'), Decimal('1077000.0000'), 46, 'MALE', 'SWER', 'JIMMA'),
#  (6, 6, 0, 4400157, Decimal('2333.2600'), Decimal('123410.0000'), 52, 'MALE', 'ADDIS ABABA', 'YEKA'),
#  (7, 79, 1, 3646553, Decimal('19257.0000'), Decimal('1017125.5300'), 64, 'MALE', 'SWER', 'SHASHEMENE'),
#  (8, 4, 0, 3936320, Decimal('625.5200'), Decimal('33000.0000'), 45, 'MALE', 'OROMIYA', 'SEMERA'),
#  (9, 4, 0, 843483, Decimal('720.6200'), Decimal('38200.0000'), 47, 'MALE', 'SNNP', 'SHASHEMENE'),
#  (10, 9, 0, 4434072, Decimal('2441.8400'), Decimal('129500.0000'), 53, 'MALE', 'OROMIYA', 'YEKA'),
# ...

# %%
# %%sql
# SELECT count([TXN_ID]) total_customer
#       ,[GENDER]
#   FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND] group by GENDER order by count([TXN_ID]) desc
# Out:
#  * mssql+pyodbc://AntiLaundering:***@sql_server
# Done.
# [(1323688, 'MALE'), (169870, 'FEMALE')]

# %%
total_txn= %sql SELECT count([TXN_ID]) total_customer   FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND] 
total_txn
# Out:
#  * mssql+pyodbc://AntiLaundering:***@sql_server
# Done.
# [(1493558,)]

# %%
df=%sql SELECT count([TXN_ID]) total_customer,[SUSPECTFRAUD],[GENDER]FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND] group by GENDER,[SUSPECTFRAUD] order by count([TXN_ID]) desc;
df
# Out:
#  * mssql+pyodbc://AntiLaundering:***@sql_server
# Done.
# [(1311850, 0, 'MALE'),
#  (169864, 0, 'FEMALE'),
#  (11838, 1, 'MALE'),
#  (6, 1, 'FEMALE')]

# %%
df_nonFraud=%sql SELECT count([TXN_ID]) total_customer,[SUSPECTFRAUD],[GENDER]FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND] WHERE [SUSPECTFRAUD]=0 group by GENDER,[SUSPECTFRAUD] order by count([TXN_ID]) desc;
df_nonFraud
# Out:
#  * mssql+pyodbc://AntiLaundering:***@sql_server
# Done.
# [(1311850, 0, 'MALE'), (169864, 0, 'FEMALE')]

# %%
sql_FRAUD=%sql SELECT count([TXN_ID]) total_customer,[GENDER]FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND] WHERE [SUSPECTFRAUD]=1 group by GENDER order by count([TXN_ID]) desc;
sql_FRAUD
# Out:
#  * mssql+pyodbc://AntiLaundering:***@sql_server
# Done.
# [(11838, 'MALE'), (6, 'FEMALE')]

# %%
df_FRAUD = pd.DataFrame(sql_FRAUD,columns=['total_customer', 'GENDER'])
df_FRAUD
# Out:
#    total_customer  GENDER
# 0           11838    MALE
# 1               6  FEMALE

# %%
df_FRAUD.columns
# Out:
# Index(['total_customer', 'GENDER'], dtype='object')

# %%
Gender = df_FRAUD['GENDER']
total_customer = df_FRAUD['total_customer']
 
# Figure Size
fig = pyplt.figure(figsize =(10, 7))
 
# Horizontal Bar Plot
col=['green','red']
pyplt.bar(Gender, total_customer, width=0.3, color=col)
font1={'color':'blue', 'size':'20', 'family':'cambria'}
font2={'color':'red', 'size':'20', 'family':'cambria'}
font3={'color':'green', 'size':'20', 'family':'cambria'}
pyplt.title('Gender Distrubition Graph', fontdict=font1) 
pyplt.xlabel('Gender', fontdict=font3)
pyplt.ylabel('Number of customers', fontdict=font2)
#pyplt.pcolor('green')
 
# Show Plot
pyplt.show()

# %%
# %%sql
# SELECT count([TXN_ID]) total_customer,[SUSPECTFRAUD]
#       ,[GENDER]
#       ,[REGIONNAME]
#   FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND] group by [GENDER],[SUSPECTFRAUD]
#       ,[REGIONNAME] order by count([TXN_ID]) desc
# Out:
#  * mssql+pyodbc://AntiLaundering:***@sql_server
# Done.
# [(399673, 0, 'MALE', 'OROMIYA'),
#  (329531, 0, 'MALE', 'ADDIS ABABA'),
#  (211754, 0, 'MALE', 'AMHARA'),
#  (148322, 0, 'MALE', 'SNNP'),
#  (83269, 0, 'FEMALE', 'ADDIS ABABA'),
#  (55048, 0, 'MALE', 'SOMALE'),
#  (49934, 0, 'MALE', 'SIDAMA'),
#  (33922, 0, 'FEMALE', 'OROMIYA'),
#  (33412, 0, 'MALE', 'SWER'),
#  (25095, 0, 'FEMALE', 'AMHARA'),
#  (23915, 0, 'MALE', 'TIGRAY'),
#  (20807, 0, 'MALE', 'DIRE DAWA'),
#  (13251, 0, 'MALE', 'AFAR'),
#  (13210, 0, 'MALE', 'BENSHANGUL GUMUZ'),
#  (11500, 0, 'FEMALE', 'SNNP'),
#  (7977, 0, 'MALE', 'HARARI'),
#  (5016, 0, 'MALE', 'GAMBELLA'),
#  (4749, 0, 'FEMALE', 'SIDAMA'),
#  (3509, 1, 'MALE', 'SNNP'),
#  (2741, 0, 'FEMALE', 'DIRE DAWA'),
#  (2390, 0, 'FEMALE', 'SOMALE'),
#  (2155, 1, 'MALE', 'TIGRAY'),
#  (1902, 1, 'MALE', 'OROMIYA'),
#  (1806, 1, 'MALE', 'SWER'),
#  (1525, 0, 'FEMALE', 'SWER'),
#  (1406, 1, 'MALE', 'SOMALE'),
#  (1267, 0, 'FEMALE', 'HARARI'),
# ...

# %%
FRAUD_region=%sql SELECT count([TXN_ID]) total_customer,[REGIONNAME]  FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND] where [SUSPECTFRAUD]=1 group by [REGIONNAME] order by count([TXN_ID]) desc
FRAUD_region
# Out:
#  * mssql+pyodbc://AntiLaundering:***@sql_server
# Done.
# [(3510, 'SNNP'),
#  (2157, 'TIGRAY'),
#  (1904, 'OROMIYA'),
#  (1807, 'SWER'),
#  (1406, 'SOMALE'),
#  (561, 'SIDAMA'),
#  (307, 'AMHARA'),
#  (76, 'BENSHANGUL GUMUZ'),
#  (61, 'ADDIS ABABA'),
#  (25, 'DIRE DAWA'),
#  (15, 'HARARI'),
#  (14, 'GAMBELLA'),
#  (1, 'AFAR')]

# %%
df_FRAUD_region = pd.DataFrame(FRAUD_region,columns=['total_customer', 'REGIONNAME'])
df_FRAUD_region
# Out:
#     total_customer        REGIONNAME
# 0             3510              SNNP
# 1             2157            TIGRAY
# 2             1904           OROMIYA
# 3             1807              SWER
# 4             1406            SOMALE
# 5              561            SIDAMA
# 6              307            AMHARA
# 7               76  BENSHANGUL GUMUZ
# 8               61       ADDIS ABABA
# 9               25         DIRE DAWA
# 10              15            HARARI
# 11              14          GAMBELLA
# 12               1              AFAR

# %%
REGIONNAME = df_FRAUD_region['REGIONNAME']
total_txn = df_FRAUD_region['total_customer']
 
# Figure Size
fig = pyplt.figure(figsize =(20, 10))
 
# Horizontal Bar Plot
col=['green', 'y','orange','b','r','k']
pyplt.bar(REGIONNAME, total_txn, color=col)
 
pyplt.title('Region Distrubition Graph', fontdict=font1) 
pyplt.xlabel('Region', fontdict=font3)
pyplt.ylabel('Number of customers', fontdict=font2)
# Show Plot
pyplt.show()

# %%
FRAUD_district=%sql SELECT count([TXN_ID]) total_customer,[DISTRICTNAME]  FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND] where [SUSPECTFRAUD]=1 group by [DISTRICTNAME] order by count([TXN_ID]) desc
FRAUD_district
# Out:
#  * mssql+pyodbc://AntiLaundering:***@sql_server
# Done.
# [(5406, 'YEKA'),
#  (1721, 'WOLAITA SODO'),
#  (1083, 'WOLDIA'),
#  (920, 'NIFAS SILK'),
#  (793, 'SHASHEMENE'),
#  (408, 'MERKATO'),
#  (383, 'SEMERA'),
#  (276, 'NEKEMTE'),
#  (213, 'SHIRE'),
#  (173, 'METTU'),
#  (126, 'JIJIGA'),
#  (56, 'KOLFE'),
#  (50, 'MEGENAGNA'),
#  (49, 'GONDER'),
#  (38, 'JIMMA'),
#  (30, 'KIRKOS'),
#  (23, 'HOSSANA'),
#  (21, 'HAWASSA'),
#  (19, 'DIRE DAWA'),
#  (13, 'DEBRE MARKOS'),
#  (12, 'MEKELLE'),
#  (8, 'BALE ROBE'),
#  (7, 'DESSIE'),
#  (5, 'ASSELA'),
#  (4, 'BAHIR DAR'),
#  (3, 'DEBRE BREHAN'),
#  (2, 'DILLA'),
#  (2, 'BOLE')]

# %%
df_FRAUD_district = pd.DataFrame(FRAUD_district,columns=['total_customer', 'DISTRICTNAME'])

# %%
DISTRICTNAME = df_FRAUD_district['DISTRICTNAME']
total_customer = df_FRAUD_district['total_customer']
 
# Figure Size
fig = pyplt.figure(figsize =(20, 10))
col=['green', 'y','b','r','k']
#Pie chart 
pyplt.pie(total_customer, labels=DISTRICTNAME, autopct='%2.1f%%')
# Horizontal Bar Plot
#pyplt.bar(DISTRICTNAME, total_customer, color=col)
pyplt.title('District Distrubition Graph',fontdict=font1) 
#pyplt.xlabel('District',fontdict=font3)
#pyplt.ylabel('Number of customers',fontdict=font2)
 
# Show Plot
pyplt.show()

# %%
FRAUD_age=%sql SELECT count(*) total_customer, * FROM (SELECT case   when Age <18 then 'Under 18'   when Age between 18 and 30 then '18-30'   when Age between 31 and 50 then '31-50'   when Age between 51 and 65 then '51-65'   when  Age>65 then '>65' END as Age FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND] where [SUSPECTFRAUD]=1 ) t  group by Age order by count(*)
FRAUD_age
# Out:
#  * mssql+pyodbc://AntiLaundering:***@sql_server
# Done.
# [(1027, '31-50'), (4220, '>65'), (6597, '51-65')]

# %%
df_FRAUD_age = pd.DataFrame(FRAUD_age,columns=['total_customer', 'Age'])
df_FRAUD_age
# Out:
#    total_customer    Age
# 0            1027  31-50
# 1            4220    >65
# 2            6597  51-65

# %%
Age = df_FRAUD_age['Age']
total_customer = df_FRAUD_age['total_customer']
 
# Figure Size
fig = pyplt.figure(figsize =(10, 7))
 
# Horizontal Bar Plot
col=['green', 'y', 'b']
pyplt.bar(Age, total_customer, width=0.5, color=col)
pyplt.title('Age Distrubition Graph',fontdict=font1) 
pyplt.xlabel('Age', fontdict=font3)
pyplt.ylabel('Number of customers', fontdict=font2)
 
 
# Show Plot
pyplt.show()

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
col_names = ['TXN_ID','TOTAL_TNX','SUSPECTFRAUD','DEBIT_CUSTOMER','USD_EQUIV_BALANCE','CREDIT_AMOUNT','AGE','GENDER','REGIONNAME','DISTRICTNAME']
# load dataset

# %%
sql_allData=%sql SELECT  [TXN_ID]      ,[TOTAL_TNX]      ,[SUSPECTFRAUD]      ,[DEBIT_CUSTOMER]      ,[USD_EQUIV_BALANCE]      ,[CREDIT_AMOUNT]      ,[AGE]      ,[GENDER]      ,[REGIONNAME]      ,[DISTRICTNAME]  FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND]
df_Fraud_All = pd.DataFrame(sql_allData,columns=col_names)
#df_Fraud_All
df_Fraud_All.head(10)
# Out:
#  * mssql+pyodbc://AntiLaundering:***@sql_server
# Done.
#    TXN_ID  TOTAL_TNX  SUSPECTFRAUD  DEBIT_CUSTOMER USD_EQUIV_BALANCE  \
# 0       1          8             0         4599132        29827.8000
# 1       2          4             0         4530324         5545.9700
# 2       3         11             0         1456210         4705.6500
# 3       5          6             0          947470        20301.8700
# 4       6          6             0         4400157         2333.2600
# 5       7         79             1         3646553        19257.0000
# 6       8          4             0         3936320          625.5200
# 7       9          4             0          843483          720.6200
# 8      10          9             0         4434072         2441.8400
# 9      11          7             0          413452         5221.4600
#
#   CREDIT_AMOUNT  AGE GENDER        REGIONNAME DISTRICTNAME
# 0  1577540.0000   42   MALE           OROMIYA      MERKATO
# ...

# %%
gender = {'MALE': 0,'FEMALE': 1}
district = {'ADAMA':0,'AMBO':1,'ARADA':2,'ASSELA':3,'BAHIR DAR':4,'BALE ROBE':5,'BOLE':6,'CONSUMER EAST ADDIS':7,'CONSUMER NORTH ADDIS':8,'CONSUMER SOUTH ADDIS':9,'CONSUMER WEST ADDIS':10,'DEBRE BREHAN':11,'DEBRE MARKOS':12,'DESSIE':13,'DILLA':14,'DIRE DAWA':15,'GONDER':16,'HAWASSA':17,'HOSSANA':18,'JIJIGA':19,'JIMMA':20,'KIRKOS':21,'KOLFE':22,'MEGENAGNA':23,'MEKELLE':24,'MERKATO':25,'METTU':26,'NEKEMTE':27,'NIFAS SILK':28,'SEMERA':29,'SHASHEMENE':30,'SHIRE':31,'WOLAITA SODO':32,'WOLDIA':33,'YEKA':34}
region={'ADDIS ABABA':0,'AFAR':1,'AMHARA':2,'BENSHANGUL GUMUZ':3,'DIRE DAWA':4,'GAMBELLA':5,'HARARI':6,'OROMIYA':7,'SIDAMA':8,'SNNP':9,'SOMALE':10,'SWER':11,'TIGRAY':12}

 # traversing through dataframe
# Gender column and writing
# values where key matches
df_Fraud_All_raverse=df_Fraud_All.copy()
df_Fraud_All_raverse.GENDER = [gender[item] for item in df_Fraud_All_raverse.GENDER]
df_Fraud_All_raverse.REGIONNAME = [region[item] for item in df_Fraud_All_raverse.REGIONNAME]
df_Fraud_All_raverse.DISTRICTNAME = [district[item] for item in df_Fraud_All_raverse.DISTRICTNAME]
df_Fraud_All_raverse.head(10)
# Out:
#    TXN_ID  TOTAL_TNX  SUSPECTFRAUD  DEBIT_CUSTOMER USD_EQUIV_BALANCE  \
# 0       1          8             0         4599132        29827.8000
# 1       2          4             0         4530324         5545.9700
# 2       3         11             0         1456210         4705.6500
# 3       5          6             0          947470        20301.8700
# 4       6          6             0         4400157         2333.2600
# 5       7         79             1         3646553        19257.0000
# 6       8          4             0         3936320          625.5200
# 7       9          4             0          843483          720.6200
# 8      10          9             0         4434072         2441.8400
# 9      11          7             0          413452         5221.4600
#
#   CREDIT_AMOUNT  AGE  GENDER  REGIONNAME  DISTRICTNAME
# 0  1577540.0000   42       0           7            25
# 1   292500.0000   47       0           3            27
# ...

# %%
#split dataset in features and target variable
feature_cols = ['TOTAL_TNX','DEBIT_CUSTOMER','USD_EQUIV_BALANCE','CREDIT_AMOUNT','AGE','GENDER','REGIONNAME','DISTRICTNAME']
 
X = df_Fraud_All_raverse[feature_cols] # Features
y = df_Fraud_All_raverse.SUSPECTFRAUD # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9933916280564558

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('laundering.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18492/823399468.py in <module>
#       1 from sklearn.tree import export_graphviz
# ----> 2 from sklearn.externals.six import StringIO
#       3 from IPython.display import Image
#       4 import pydotplus
#       5
#
# ModuleNotFoundError: No module named 'sklearn.externals.six'

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9950520903077211

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('laundering.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18492/1508016855.py in <module>
# ----> 1 from sklearn.externals.six import StringIO
#       2 from IPython.display import Image
#       3 from sklearn.tree import export_graphviz
#       4 import pydotplus
#       5 dot_data = StringIO()
#
# ModuleNotFoundError: No module named 'sklearn.externals.six'
