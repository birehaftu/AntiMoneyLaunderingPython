# %%
pip install ipython-sql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached ipython_sql-0.4.1-py3-none-any.whl (21 kB)
# ...
#   Using cached sqlparse-0.4.3-py3-none-any.whl (42 kB)
# ...
#   Using cached prettytable-0.7.2.zip (28 kB)
# ...
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13714 sha256=fc70c86214ee4871db077f7db898118ed79921130598616158b36df0a8d86088
#   Stored in directory: c:\users\birhane\appdata\local\pip\cache\wheels\75\f7\28\77a076f1fa8cbeda61aca712815d04d7a32435f04a26a2dd7b
# Successfully built prettytable
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script sqlformat.exe is installed in 'C:\Users\birhane\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pandas as pd
import pyodbc
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
# %load_ext sql

# %%
# %sql mssql+pyodbc://AntiLaundering:AntiLaundering@pyodbc

# %%
# %%sql
# SELECT top(1000) [TXN_ID]
#       ,[TOTAL_TNX]
#       ,[SUSPECTFRAUD]
#       ,[DEBIT_CUSTOMER]
#       ,[USD_EQUIV_BALANCE]
#       ,[CREDIT_AMOUNT]
#       ,[AGE]
#       ,[GENDER]
#       ,[REGIONNAME]
#       ,[DISTRICTNAME]
#   FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND]
# Out:
#  * mssql+pyodbc://AntiLaundering:***@pyodbc
# Done.
# [(1, 2, 0, 'NONE', 1742242, Decimal('1898.2600'), Decimal('100000.0000'), 43, 'MALE', 'AMHARA', 'DEBRE BREHAN'),
#  (2, 2, 1, 'BLACKMARKET', 3855734, Decimal('17402.1100'), Decimal('920920.0000'), 52, 'MALE', 'AMHARA', 'DESSIE'),
#  (3, 8, 1, 'BLACKMARKET', 4599132, Decimal('29827.8000'), Decimal('1577540.0000'), 42, 'MALE', 'OROMIYA', 'MERKATO'),
#  (4, 4, 1, 'BLACKMARKET', 4530324, Decimal('5545.9700'), Decimal('292500.0000'), 47, 'MALE', 'BENSHANGUL GUMUZ', 'NEKEMTE'),
#  (5, 11, 1, 'BLACKMARKET', 1456210, Decimal('4705.6500'), Decimal('248200.0000'), 56, 'MALE', 'OROMIYA', 'MEGENAGNA'),
#  (6, 17, 1, 'BLACKMARKET', 4198434, Decimal('5302.4800'), Decimal('280295.7800'), 55, 'OTHERS', 'AMHARA', 'YEKA'),
#  (7, 6, 1, 'BLACKMARKET', 947470, Decimal('7263.7100'), Decimal('384000.0000'), 46, 'MALE', 'SWER', 'JIMMA'),
# ...

# %%
# %%sql
# SELECT [TXN_ID]
#       ,[TOTAL_TNX]
#       ,[SUSPECTFRAUD]
#       ,[DEBIT_CUSTOMER]
#       ,[USD_EQUIV_BALANCE]
#       ,[CREDIT_AMOUNT]
#       ,[AGE]
#       ,[GENDER]
#       ,[REGIONNAME]
#       ,[DISTRICTNAME]
#   FROM [AntiLaundering].[dbo].[FraudDetectedTrendAND]
# Out:
#  * mssql+pyodbc://AntiLaundering:***@pyodbc
# Done.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SELECT [TXN_ID]\n      ,[TOTAL_TNX]\n      ,[SUSPECTFRAUD]\n      ,[DETECTED_BY]\n      ,[DEBIT_CUSTOMER]\n      ,[USD_EQUIV_BALANCE]\n      ,[CREDIT_AMOUNT]\n      ,[AGE]\n      ,[GENDER]\n      ,[REGIONNAME]\n      ,[DISTRICTNAME]\n  FROM [AntiLaundering].[dbo].[FraudDetectedBlackCountFiltered]\n')
#
# File C:\Anaconda\lib\site-packages\IPython\core\displayhook.py:262, in DisplayHook.__call__(self, result)
#     260 self.start_displayhook()
#     261 self.write_output_prompt()
# --> 262 format_dict, md_dict = self.compute_format_data(result)
#     263 self.update_user_ns(result)
#     264 self.fill_exec_result(result)
#
# ...
